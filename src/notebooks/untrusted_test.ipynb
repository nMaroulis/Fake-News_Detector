# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import sys, io, os, errno, fileinput, csv
import collections as cl
from os import path
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
import matplotlib as plt
import seaborn as sb
from sklearn import svm
from sklearn import metrics
from sklearn.model_selection import cross_val_score
import tensorflow as tf
from tensorflow import keras as kr
import itertools
import warnings
from sklearn.model_selection import StratifiedKFold
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import cross_val_score
from joblib import dump, load


trainset_file = "../../Datasets/the_onion.csv"
train_df = pd.read_csv(trainset_file,  sep=',')
df = train_df['domain']
df = df.drop_duplicates()

trainset_file1 = "../../Datasets/train_2.csv"
train_df1 = pd.read_csv(trainset_file1,  sep=',')
df1 = train_df1[(train_df1['spam_score'] > 0.7)]
df1 = df1['site_url']
df1 = df1.drop_duplicates()
df.head(3)
# Out:
# 0           theonion.com
# 1               kwqc.com
# 4    sports.theonion.com
# Name: domain, dtype: object

# %%
UNTRUSTED = df.values.tolist()
UNTRUSTED.extend(df1.values.tolist())

# %%
UNTRUSTED.remove('google.com')
UNTRUSTED.remove('youtube.com')
UNTRUSTED.remove('analytics.twitter.com')
UNTRUSTED.remove('docs.google.com')
UNTRUSTED.remove('twitter.com')
UNTRUSTED.remove('m.youtube.com')
UNTRUSTED.remove('dailymail.co.uk')
UNTRUSTED.remove('instagram.com')
UNTRUSTED.remove('cnn.com')
UNTRUSTED
# Out:
# ['theonion.com',
#  'kwqc.com',
#  'sports.theonion.com',
#  'youtu.be',
#  'entertainment.theonion.com',
#  'i.redd.it',
#  'local.theonion.com',
#  'lifestyle.clickhole.com',
#  'politics.theonion.com',
#  'clickhole.com',
#  'news.clickhole.com',
#  'soundcloud.com',
#  'patriothole.clickhole.com',
#  'newsthump.com',
#  'google.ca',
#  'thehardtimes.net',
#  'iflscience.com',
#  'newyorker.com',
#  'comicbook.com',
#  'storypick.com',
#  'deadspin.com',
#  'm.dailyhunt.in',
#  'waterfordwhispersnews.com',
#  'thebeaverton.com',
#  'hollywoodreporter.com',
#  'resistancehole.clickhole.com',
#  'emttime.com',
#  'themillennialsnowflake.com',
#  'splinternews.com',
#  'babylonbee.com',
#  'theguardian.com',
#  'voices.clickhole.com',
#  'kcci.com',
#  'desmoinesregister.com',
#  'sunday-herald.com',
#  'somethingawful.com',
#  'huzlers.com',
#  'ebony.com',
#  'anarchostatist.com',
#  'duffelblog.com',
#  'inews.co.uk',
#  'thehill.com',
#  'm.betootaadvocate.com',
#  'quizzes.clickhole.com',
#  'i.imgur.com',
#  'empiremktxgjovhm.onion',
#  'sfashion.online',
#  'ndtv.com',
#  'reductress.com',
#  'thestar.com.my',
#  'wcpo.com',
#  'standard.co.uk',
#  'meduza.io',
#  'interactives.clickhole.com',
#  'theverge.com',
#  'liberaldarkness.com',
#  'lincolnshirelive.co.uk',
#  'uokhun.uk',
#  'falmouthpacket.co.uk',
#  'ajaisblog.com',
#  'clickventures.clickhole.com',
#  'pushmio.tk',
#  '/r/TheOnion/comments/9g8lp2/ya_juggalo/',
#  '8shit.net',
#  'washingtonpost.com',
#  'themorningsquire.com.au',
#  'worldnewsdailyreport.com',
#  'cbc.ca',
#  'cdn.ebaumsworld.com',
#  'newsweek.com',
#  'abcnews.go.com',
#  'foxnews-us.com',
#  'officialmikepence.com',
#  'thebytedaily.com',
#  'hurriyetdailynews.com',
#  'imgur.com',
#  'sportspickle.com',
#  'thediscosloth.kinja.com',
#  'foxnews.com',
#  'businessinsider.com',
#  'news.avclub.com',
#  '/r/TheOnion/comments/8vt9x3/french_government_asks_for_statue_of_liberty_back/',
#  'fox47news.com',
#  'breakingburgh.com',
#  'onionsocial.com',
#  'essentiallibertynow.com',
#  'ogvtjb6bq4aco4s2ejrxsroswnbxvaxfvan4kjv636h5xvkhhqeokryd.onion',
#  'fortnite-gifts.com',
#  'dinar.tv',
#  'moviezopenload.tk',
#  'agu.edu.in',
#  'isthmus.com',
#  'thestar.com',
#  'nbcnews.com',
#  'iftarnightlynews.com',
#  'thebulletin.org',
#  'celebritycrush.org',
#  'betootaadvocate.com',
#  'syracuse.com',
#  'huntingpicks.com',
#  'pasadenastarnews.com',
#  'reddit.com',
#  'medium.com',
#  'bbc.co.uk',
#  'owensonion.wordpress.com',
#  'modernfarmer.com',
#  'theweek.co.uk',
#  'thevalleyreport.com',
#  'bbc.com',
#  'sync.fongaboo.com',
#  'marketwatch.com',
#  'vancouversun.com',
#  'sites.google.com',
#  'newsfordogs.com',
#  'yewnorker.com',
#  'salon.com',
#  'metro.co.uk',
#  'thesun.co.uk',
#  'rawstory.com',
#  'scontent-iad3-1.xx.fbcdn.net',
#  'espn.com',
#  'vanityfair.com',
#  'dhntv.com',
#  'cnbc.com',
#  'google.com.au',
#  'bloomberg.com',
#  'thestormerdaily.com',
#  'express.co.uk',
#  'facebook.com',
#  'chicagotribune.com',
#  'dailyhowler.org',
#  'theshovel.com.au',
#  'techly.com.au',
#  'theunaustralian.net',
#  'm.metrotimes.com',
#  'dailysnark.com',
#  'the-postillon.com',
#  'out.com',
#  'akramdaily.com',
#  'theantwerpoyster.com',
#  'bluestar-ranch.com',
#  'theage.com.au',
#  'worldbitcoinex.com',
#  'telegraph.co.uk',
#  'euronews.com',
#  '666surveillancesystem.com',
#  'dailywire.com',
#  'millennialmorms.com',
#  'christwire.org',
#  'teespring.com',
#  'allafrica.com',
#  'hetbelegvanantwerpen.com',
#  'sputniknews.com',
#  'blog.timesunion.com',
#  '965kvki.com',
#  'reuters.com',
#  'usnews.com',
#  'wltx.com',
#  'manymanyadventures.com',
#  'vox.com',
#  'alwaystrending.io',
#  'm.imgur.com',
#  'springthenoise.com',
#  'thejournal.ie',
#  'be-manipulated.beforeitsnews.com',
#  'chaser.com.au',
#  'mississippiherald.com',
#  'abc7.com',
#  'i.reddituploads.com',
#  'theinsanemustang.com',
#  'dailycaller.com',
#  'twincities.com',
#  'mtlblog.com',
#  'en.dailypakistan.com.pk',
#  'play.google.com',
#  'indiatoday.intoday.in',
#  'clickorlando.com',
#  'orig06.deviantart.net',
#  'avclub.com',
#  'en.mediamass.net',
#  'beertap.tv',
#  'deadstate.org',
#  'time.com',
#  'wsbt.com',
#  'dundermilfland.com',
#  'stuff.co.nz',
#  'spaces.archilogic.com',
#  'icitech.org',
#  'usa.chinadaily.com.cn',
#  'trumppotato.com',
#  'uk.businessinsider.com',
#  'media.dish.allrecipes.com',
#  'i.onionstatic.com',
#  'actionnewsjax.com',
#  'cookingwithoutborders.files.wordpress.com',
#  'nzherald.co.nz',
#  'cdn.theatlantic.com',
#  'whdh.com',
#  'trump.furniture',
#  'whatsupic.com',
#  'gomerblog.com',
#  'sfgate.com',
#  'fox8.com',
#  'belfastandfurious.com',
#  'onion.com',
#  'gawken.com',
#  'bostonleader.com',
#  'independent.co.uk',
#  'clckhl.co',
#  'theodysseyonline.com',
#  'themideastbeast.com',
#  'andnotafockwasgiven.com',
#  'amp.ibtimes.co.uk',
#  'zerohedge.com',
#  'store.steampowered.com',
#  'charlotteobserver.com',
#  'jamaicaobserver.com',
#  'walesoncraic.com',
#  'thisamericanlife.org',
#  'theoptic.co.uk',
#  'legorafi.fr',
#  'onionstudios.com',
#  'starwipe.com',
#  'thedailymash.co.uk',
#  'dormtoday.com',
#  'nj.com',
#  'shailendrajaiswal.com',
#  'fuacantanj2vhfpw.onion',
#  'motherjones.com',
#  'staradvertiser.com',
#  'quora.com',
#  'sciencealert.com',
#  'badmintoncafe.com',
#  'nypost.com',
#  'failmuch.com',
#  'fakingnews.firstpost.com',
#  'yourohiovalley.com',
#  'penguinparty.net',
#  'activefitlife.com',
#  'brosil.ga',
#  'omgfoggycollec.tumblr.com',
#  'neomongolianewsnetwork.com',
#  '1stchoicefinancialgroup.com',
#  'squibnews.com',
#  'bodhiline.com',
#  'ways2shop.com',
#  'travelpersona.com',
#  'lancotanjorepowercompanyltd.com',
#  'think-forex-usa.com',
#  'suratthanithailand.com',
#  'focuslost.com',
#  'relationshipsmasterclass.com',
#  'hedefkariyer.com',
#  'unicomputadoras.com',
#  'xlflo.com',
#  'porschekiralama.com',
#  'readingtruck.com',
#  'cannamom.com',
#  'jealoussis.com',
#  'bordesleyabbey.com',
#  'cokerbrotherssalesandservice.com',
#  'superiormotorcycle.com',
#  'taotelaisi.com',
#  'stemshare.com',
#  'counterpunch.org',
#  'socceronsand.com',
#  'sfrjob.com',
#  'superiorwallsofwestvirginia.com',
#  'mc-guganautocad.com',
#  'scunthorpetelegraph.co.uk',
#  'whereswetzler.com',
#  'peacefulmassage.com',
#  'certifiedlettertool.com',
#  'dron.usluga-goda.com',
#  'x7bijvq2.formicalogistics.com',
#  'goybwiema.formicalogistics.com',
#  'siedl9z35.formicalogistics.com',
#  'thefreethoughtproject.com',
#  'smartweaving.com',
#  'google.com.ua',
#  'moscowwalking.com',
#  'premium36.com',
#  'wcombinator.com',
#  'urbanimagemagazine.com',
#  'businessetc.thejournal.ie',
#  '13loveplanet13.ga',
#  'netforcomfort.com',
#  'zhilservice77.com',
#  'westdeliverycenter.com',
#  'intournament.com',
#  'daaotassggnanan.essayff.com',
#  'ldadaanaaaa.sxeinject.com',
#  'taditogsaan.simbaex.com',
#  'google.no',
#  'fabricws.com',
#  'andreasleine.com',
#  'aviasale-tickets.com',
#  'msgvozdkova.com',
#  'krasology.com',
#  'news.com.au',
#  'lostiiantanadtlaat.ferrohomme.com',
#  'lonnasanaasstnan.img-local.com',
#  'aiaataasoagin.mosadvoc.com',
#  'old.nasha.lv',
#  'latolsltaaaoan.gad-gets.com',
#  'siolsogtgdoa.impextorg.com',
#  'spendrevenge.com',
#  'gr0qex.world-iron.com',
#  'bitcoin-kran.com',
#  'theintercept.com',
#  'anksunamun.com',
#  'redditdating.tumblr.com',
#  'nerdist.com',
#  'news.discovery.com',
#  'ncscooper.com',
#  'npr.org',
#  'fordevillediaries.com',
#  'aadigdoant.amkkaoyw.com',
#  'alllsgaaala.iackqyaohv.com',
#  'm.facebook.com',
#  'gaital.ofokygmoc.com',
#  'alaaaa.qeowkey.com',
#  'gtaaisn.uaqwbxyoiwupz.com',
#  'lsoaglnaasl.jhouuilrojcva.com',
#  'oasaalianasis.cvyioujeaj.com',
#  'whogoesback.top',
#  'i100.independent.co.uk',
#  'go.yjneyluhah.com',
#  'zeckoqehfo.com',
#  'cosmopolitan.com',
#  'newsok.com',
#  'thespec.com',
#  'beebdddbgb.fast-page.org',
#  'evvsbdgsveeb.totalh.net',
#  'drgdrg.66ghz.com',
#  'dailykos.com',
#  'justincolucci.tumblr.com',
#  'someecards.com',
#  'townhall.com',
#  'wired.com',
#  'trueactivist.com',
#  'alien-species.mostextremenews.com',
#  'self.TheOnion',
#  'amazon.com',
#  'dazeddigital.com',
#  'redditmetrics.com',
#  'ladunliadinews.com',
#  'dailycurrant.com',
#  'panarabiaenquirer.com',
#  'factually.gizmodo.com',
#  'yuviral.com',
#  'mediaite.com',
#  'randallstarr.tumblr.com',
#  'thoughtnotebook.org',
#  'yahoo.com',
#  'countercurrentnews.com',
#  'bigamericannews.com',
#  'rt.com',
#  'v.theonion.com',
#  'stanfordflipside.com',
#  'bleacherreport.com',
#  'blog.sfgate.com',
#  'buzzfeed.com',
#  'mobile.bloomberg.com',
#  'theantimedia.org',
#  'timesdispatch.com',
#  'twitch.tv',
#  'memecrunch.com',
#  'pcgamer.com',
#  'usatoday.com',
#  'themarysue.com',
#  'utsandiego.com',
#  'mirror.co.uk',
#  'topekasnews.com',
#  'bizjournals.com',
#  'treehugger.com',
#  'ronaldo-messi.net',
#  '100percentfedup.com',
#  '21stcenturywire.com',
#  'ahtribune.com',
#  'americanlookout.com',
#  'anonhq.com',
#  'barenakedislam.com',
#  'beforeitsnews.com',
#  'bipartisanreport.com',
#  'collective-evolution.com',
#  'consciouslifenews.com',
#  'counterpunch.org',
#  'dailystormer.com',
#  'dailywire.com',
#  'dennismichaellynch.com',
#  'departed.co',
#  'donaldtrumpnews.co',
#  'elmundotoday.com',
#  'ewao.com',
#  'gomerblog.com',
#  'govtslaves.info',
#  'guardianlv.com',
#  'ijr.com',
#  'informationclearinghouse.info',
#  'intrepidreport.com',
#  'journal-neo.org',
#  'magafeed.com',
#  'miniplanet.us',
#  'morningnewsusa.com',
#  'nakedcapitalism.com',
#  'newsthump.com',
#  'nutritionfacts.org',
#  'occupydemocrats.com',
#  'off-guardian.org',
#  'opednews.com',
#  'prisonplanet.com',
#  'redflagnews.com',
#  'rt.com',
#  'sgtreport.com',
#  'theantimedia.org',
#  'theduran.com',
#  'theearthchild.co.za',
#  'thefederalistpapers.org',
#  'theonion.com',
#  'therussophile.org',
#  'truthfeed.com',
#  'undergroundhealth.com',
#  'unz.com',
#  'usatwentyfour.com',
#  'usuncut.com',
#  'voltairenet.org']
