# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import csv
import io, os, errno
import fileinput
import collections as cl
from os import path
from wordcloud import WordCloud
import nltk
#nltk.download("stopwords")
from nltk.corpus import stopwords 
#from nltk.tokenize import word_tokenize 

stop_words = set(stopwords.words('english'))

w_path = "../../static/wordcloud.txt"

def delete_wordcloud_file(file_path):
    try:
        os.remove(file_path)
    except OSError:
        pass

delete_wordcloud_file(w_path)

wordcloud_file = open(w_path, "w")


trainset_file = "../../Datasets/the_onion.csv"
train_df = pd.read_csv(trainset_file,  sep=',')
trainset_file1 = "../../Datasets/train_2.csv"
train_df1 = pd.read_csv(trainset_file1,  sep=',')
train_df1[(train_df1['spam_score'] > 0.6)]
train_df1
# Out:
#                                            uuid  ord_in_thread  \
# 0      6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1      2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
# 2      c70e149fdd53de5e61c29281100b9de0ed268bc3              0
# 3      7cf7c15731ac2a116dd7f629bd57ea468ed70284              0
# 4      0206b54719c7e241ffe0ad4315b808290dbe6c0f              0
# 5      8f30f5ea14c9d5914a9fe4f55ab2581772af4c31              0
# 6      d3cc0fe38f41a59f7c48f8c3528ca5f74193148f              0
# 7      b4bbf8b5c19e8864f5257832a58b81ef4ed2d4e4              0
# 8      a19aabaa5a61eb8bc22fadaaa003e5fbba5c4bf6              0
# 9      f54d8e13010d0a79893995ee65360ad4b38b5a35              0
# 10     4d3faf17519cfa46ca754ab8068428818dbb2bf3              0
# 11     7f90d71cc69893f4c91e8a55f2c4da52d88cd7c1              0
# 12     fd2c048d7e03f7260a8d75725b0441c627578f1a              0
# 13     c8d4c0a88af223f1b41e3e966ecd98ceb22ab5fb              0
# ...

# %%
def generate_wordcloud_txt(df, txt):
    for index, row in df.iterrows():
    
        filtered_sentence = [w for w in row[5].split() if not w in stop_words] 
        txt.write(" ".join(str(x) for x in filtered_sentence))
        
    
def generate_wordcloud_image(txt_path):

    text = open(txt_path).read()
    wordcloud = WordCloud(max_font_size=40).generate(text)
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
generate_wordcloud_txt(train_df1[(train_df1['spam_score'] > 0.6)].astype('U'), wordcloud_file)
wordcloud_file.close()

# %%
generate_wordcloud_image(w_path)
